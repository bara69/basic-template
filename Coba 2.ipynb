# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
path_to_csv = 'C:/Users/ASUS/Documents/Tubes/DataTubes.csv'
df = pd.read_csv(path_to_csv)
print("Columns:")
print(df.columns)
display(df)
# Out:
# Columns:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='object')
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     29    1   1     130   204    0        0       202     0        0    2
# 1     34    1   3     118   182    0        0       174     0        0    2
# 2     34    0   1     118   210    0        1       192     0        7    2
# 3     35    0   0     138   183    0        1       182     0       14    2
# 4     35    1   1     122   192    0        1       174     0        0    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   71    0   2     110   265    1        0       130     0        0    2
# 299   71    0   0     112   149    0        1       125     0       16    1
# 300   74    0   1     120   269    0        0       121     1        2    2
# ...

# %%
TekananDarahTinggi = df[df['trtbps'] > 140]
TekananDarahTinggi
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 18    40    1   0     152   223    0        1       181     0        0    2
# 31    42    1   3     148   244    0        0       178     0        8    2
# 37    43    1   0     150   247    0        1       171     0       15    2
# 62    45    1   0     142   309    0        0       147     1        0    1
# 64    46    0   2     142   177    0        0       160     1       14    0
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 291   69    1   3     160   234    1        0       131     0        1    1
# 293   70    1   1     156   245    0        0       143     0        0    2
# 294   70    1   0     145   174    0        1       125     1       26    0
# 296   70    1   2     160   269    0        1       112     1       29    1
# 297   71    0   1     160   302    0        1       162     0        4    2
#
#      caa  thall  output
# 18     0      3       0
# ...

# %%
DJUmur40 = TekananDarahTinggi[TekananDarahTinggi['age']<50]
DJUmur40
# Out:
#     age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 18   40    1   0     152   223    0        1       181     0        0    2
# 31   42    1   3     148   244    0        0       178     0        8    2
# 37   43    1   0     150   247    0        1       171     0       15    2
# 68   46    1   2     150   231    0        1       147     0       36    1
#
#     caa  thall  output
# 18    0      3       0
# 31    2      2       1
# 37    0      2       1
# 68    0      2       0

# %%
DJUmurU60 = TekananDarahTinggi[TekananDarahTinggi['age']<60]
DJUmur50 = DJUmurU60[DJUmurU60['age']>=50]
DJUmur50
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 92    50    1   0     150   243    0        0       128     0       26    1
# 94    50    1   0     144   200    0        0       126     1        9    1
# 107   52    1   2     172   199    1        1       162     0        5    2
# 112   52    1   3     152   298    1        1       178     0       12    1
# 124   53    1   0     142   226    0        0       111     1        0    2
# 131   54    1   2     150   232    0        0       165     0       16    2
# 137   54    0   2     160   201    0        1       163     0        0    2
# 141   54    1   1     192   283    0        0       195     0        0    2
# 149   55    1   0     160   289    0        0       145     1        8    1
# 150   55    0   0     180   327    0        2       117     1       34    1
# 159   56    0   0     200   288    1        0       133     1        4    0
# ...

# %%
DJUmurU70 = TekananDarahTinggi[TekananDarahTinggi['age']<70]
DJUmur60 = DJUmurU70[DJUmurU70['age']>=60]
DJUmur60
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 215   60    0   3     150   240    0        1       171     0        9    2
# 222   60    0   0     150   258    0        0       157     0       26    1
# 224   61    1   2     150   243    1        1       137     1        1    1
# 231   61    1   0     148   203    0        1       161     0        0    2
# 238   62    0   0     160   164    0        0       145     0       62    0
# 242   62    0   0     150   244    0        1       154     1       14    1
# 248   63    0   0     150   407    0        0       154     0        4    1
# 253   64    0   0     180   325    0        1       154     1        0    2
# 257   64    1   3     170   227    0        0       155     0        6    1
# 264   65    0   2     155   269    0        1       148     0        8    2
# 265   65    0   2     160   360    0        0       151     0        8    2
# ...

# %%
DJUmurU80 = TekananDarahTinggi[TekananDarahTinggi['age']<80]
DJUmur70 = DJUmurU80[DJUmurU80['age']>=70]
DJUmur70
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 293   70    1   1     156   245    0        0       143     0        0    2
# 296   70    1   2     160   269    0        1       112     1       29    1
# 297   71    0   1     160   302    0        1       162     0        4    2
#
#      caa  thall  output
# 293    0      2       1
# 296    1      3       0
# 297    2      2       1

# %%
plt.figure(figsize=(15, 15))
plt.barh(TekananDarahTinggi['age'], TekananDarahTinggi['trtbps'], 1.3)
plt.barh(DJUmur50['age'], DJUmur50['trtbps'], 1.3)
plt.yticks(np.arange(min(DJUmur50['age']), max(DJUmur50['age']+1)))
plt.xticks(np.arange(min(DJUmur50['trtbps']), max(TekananDarahTinggi['trtbps']+2), 10))
plt.xticks(rotation='horizontal')
plt.title("Perbandingan Tingkat Kolesterol Penderita Penyakit Jantung dan Tidak")
bars1 = plt.barh(TekananDarahTinggi['age'], TekananDarahTinggi['trtbps'], color=sns.color_palette('dark'))
for bar in bars1:
    xval = bar.get_width()
    plt.text(xval, bar.get_y() + bar.get_height()/1.5, xval, ha='center', va='center')
bars2 = plt.barh(DJUmur50['age'], DJUmur50['chol'], color=sns.color_palette('bright'))
for bar in bars2:
    xval = bar.get_width()
    plt.text(xval, bar.get_y() + bar.get_height()/1.5, xval, ha='center', va='center')
plt.xlabel('Kolesterol', fontsize=18)
plt.ylabel('Umur', fontsize=18)
plt.tight_layout()

# %%
TekananDarahTinggi = df[df['trtbps'] > 140]
TekananDarahTinggi
Dataumur1 = TekananDarahTinggi[TekananDarahTinggi['age']<50]
Dataumur1
#umur 40 - 49
# Out:
#     age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 18   40    1   0     152   223    0        1       181     0        0    2
# 31   42    1   3     148   244    0        0       178     0        8    2
# 37   43    1   0     150   247    0        1       171     0       15    2
# 62   45    1   0     142   309    0        0       147     1        0    1
# 64   46    0   2     142   177    0        0       160     1       14    0
# 68   46    1   2     150   231    0        1       147     0       36    1
#
#     caa  thall  output
# 18    0      3       0
# 31    2      2       1
# 37    0      2       1
# 62    3      3       0
# 64    0      2       1
# 68    0      2       0

# %%
TekananDarahTinggi = df[df['trtbps'] > 140]
TekananDarahTinggi
DJUmurU60 = TekananDarahTinggi[TekananDarahTinggi['age']<60]
Dataumur2 = DJUmurU60[DJUmurU60['age']>=50]
Dataumur2
#umur 50 -59
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 92    50    1   0     150   243    0        0       128     0       26    1
# 94    50    1   0     144   200    0        0       126     1        9    1
# 107   52    1   2     172   199    1        1       162     0        5    2
# 112   52    1   3     152   298    1        1       178     0       12    1
# 124   53    1   0     142   226    0        0       111     1        0    2
# 131   54    1   2     150   232    0        0       165     0       16    2
# 137   54    0   2     160   201    0        1       163     0        0    2
# 141   54    1   1     192   283    0        0       195     0        0    2
# 149   55    1   0     160   289    0        0       145     1        8    1
# 150   55    0   0     180   327    0        2       117     1       34    1
# 159   56    0   0     200   288    1        0       133     1        4    0
# ...

# %%
TekananDarahTinggi = df[df['trtbps'] > 140]
TekananDarahTinggi
DJUmurU70 = TekananDarahTinggi[TekananDarahTinggi['age']<70]
Dataumur3 = DJUmurU70[DJUmurU70['age']>=60]
Dataumur3
#umur 60 -69
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 215   60    0   3     150   240    0        1       171     0        9    2
# 219   60    1   0     145   282    0        0       142     1       28    1
# 222   60    0   0     150   258    0        0       157     0       26    1
# 224   61    1   2     150   243    1        1       137     1        1    1
# 227   61    0   0     145   307    0        0       146     1        1    1
# 231   61    1   0     148   203    0        1       161     0        0    2
# 238   62    0   0     160   164    0        0       145     0       62    0
# 242   62    0   0     150   244    0        1       154     1       14    1
# 243   63    1   3     145   233    1        0       150     0       23    0
# 248   63    0   0     150   407    0        0       154     0        4    1
# 253   64    0   0     180   325    0        1       154     1        0    2
# ...

# %%
fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))
datatekanandarah = ["6 40", "29 50", "27 60", "4 70"]
data = [float(x.split()[0]) for x in datatekanandarah]
jumlahorang = [x.split()[-1] for x in datatekanandarah]
def func(pct, allvals):
    absolute = int(np.round(pct/100.*np.sum(allvals)))
    return f"{pct:.1f}%\n({absolute:d} persons)"
wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),
                                  textprops=dict(color="w"))
ax.legend(wedges, jumlahorang,
          title="Persons Years",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))
plt.setp(autotexts, size=8, weight="bold")
ax.set_title("Grafik Prosentase Jumlah Penderita tekananan darah")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

from matplotlib.patches import ConnectionPatch

# make figure and assign axis objects
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8.5, 5))
fig.subplots_adjust(wspace=0)

# pie chart parameters
overall_ratios = [.4, .6, .27, .29]
labels = ['Persons Years 70', 'Persons Years 40', 'Persons Years 60', 'Persons Years 50']
explode = [0.1, 0, 0, 0]
# rotate so that first wedge is split by the x-axis
angle = -180 * overall_ratios[0]
wedges, *_ = ax1.pie(overall_ratios, autopct='%1.1f%%', startangle=angle,
                     labels=labels, explode=explode)

# bar chart parameters
age_ratios = [.33, .54, .07, .06]
age_labels = ['Under 35', '35-49', '50-65', 'Over 65']
bottom = 1
width = .2

# Adding from the top matches the legend.
for j, (height, label) in enumerate(reversed([*zip(age_ratios, age_labels)])):
    bottom -= height
    bc = ax2.bar(0, height, width, bottom=bottom, color='C0', label=label,
                 alpha=0.1 + 0.25 * j)
    ax2.bar_label(bc, labels=[f"{height:.0%}"], label_type='center')

ax2.set_title('Age of approvers')
ax2.legend()
ax2.axis('off')
ax2.set_xlim(- 2.5 * width, 2.5 * width)

# use ConnectionPatch to draw lines between the two plots
theta1, theta2 = wedges[0].theta1, wedges[0].theta2
center, r = wedges[0].center, wedges[0].r
bar_height = sum(age_ratios)

# draw top connecting line
x = r * np.cos(np.pi / 180 * theta2) + center[0]
y = r * np.sin(np.pi / 180 * theta2) + center[1]
con = ConnectionPatch(xyA=(-width / 2, bar_height), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
con.set_linewidth(4)
ax2.add_artist(con)

# draw bottom connecting line
x = r * np.cos(np.pi / 180 * theta1) + center[0]
y = r * np.sin(np.pi / 180 * theta1) + center[1]
con = ConnectionPatch(xyA=(-width / 2, 0), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
ax2.add_artist(con)
con.set_linewidth(4)

plt.show()

# %%
plt.figure(figsize=(15, 15))
plt.barh(TekananDarahTinggi['age'], TekananDarahTinggi['trtbps'], 1.3)
plt.barh(DJUmur50['age'], DJUmur50['trtbps'], 1.3)
plt.yticks(np.arange(min(DJUmur50['age']), max(DJUmur50['age']+1)))
plt.xticks(np.arange(min(DJUmur50['trtbps']), max(TekananDarahTinggi['trtbps']+2), 10))
plt.xticks(rotation='horizontal')
plt.title("Perbandingan Tingkat Kolesterol Penderita Penyakit Jantung dan Tidak")
bars1 = plt.barh(TekananDarahTinggi['age'], TekananDarahTinggi['trtbps'], color=sns.color_palette('dark'))
for bar in bars1:
    xval = bar.get_width()
    plt.text(xval, bar.get_y() + bar.get_height()/1.5, xval, ha='center', va='center')
bars2 = plt.barh(DJUmur50['age'], DJUmur50['chol'], color=sns.color_palette('bright'))
for bar in bars2:
    xval = bar.get_width()
    plt.text(xval, bar.get_y() + bar.get_height()/1.5, xval, ha='center', va='center')
plt.xlabel('Kolesterol', fontsize=18)
plt.ylabel('Umur', fontsize=18)
plt.tight_layout()

# %%
plt.scatter(Terjangkit['age'], Terjangkit['chol'])
plt.scatter(TdkTerjangkit['age'], TdkTerjangkit['chol'])
plt.plot(Terjangkit['age'], Terjangkit['chol'])
plt.plot(TdkTerjangkit['age'], TdkTerjangkit['chol'])
plt.legend(['Terjangkit', 'TdkTerjangkit'])
plt.xticks(np.arange(min(TdkTerjangkit['age']), max(TdkTerjangkit['age']+1), 2.0))
plt.yticks(np.arange(min(Terjangkit['chol']), max(Terjangkit['chol']+2), 20.0))
plt.xlabel('Umur', fontsize=18)
plt.ylabel('Kolesterol', fontsize=18)
plt.tight_layout()
